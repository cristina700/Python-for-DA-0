# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1 Creating a dataframe from an array

# %% [markdown]
# ###  1.1 Option 1

# %%
#creating an array
data = np.array ([[1,4], [2,5], [3,6]])

# %%
# creating a dataframe
pd.DataFrame(data)
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  3  6

# %%
pd.DataFrame(data, index=["row1", "row2", "row3"])
# Out:
#       0  1
# row1  1  4
# row2  2  5
# row3  3  6

# %%
pd.DataFrame(data, index=["row1", "row2", "row3"], columns = ["col1", "col2"])
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
df = pd.DataFrame(data, index=["row1", "row2", "row3"], columns = ["col1", "col2"])

# %%
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# ### 1.2 Option 2

# %%
# creating an array with list shape (parecido al otro pero solo la lista, sin numpy array)
data = ([[1,4], [2,5], [3,6]])

# %%
# creating a DataFrame
pd.DataFrame(data, index=["row1", "row2", "row3"], columns = ["col1", "col2"])

# %%
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# # 2 Creating a DataFrame from a Dictionary

# %%
# lists used for this example
states= ["California", "Texas", "Florida", "New York"]
population = [39613493, 29730311, 21944577, 19299981]

# %%
#storing list for a dictionary
dict_states = {"States":states, "Population":population}

# %%
#creating the DataFrame
pd.DataFrame(dict_states)

# %%
#creating the dataframe
df=pd.DataFrame(dict_states)

# %%
#showing the dataframe
df
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %% [markdown]
# # 3 Creating a dataframe from a CSV file

# %%
# reading the csv file
pd.read_csv("StudentsPerformance.csv")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#defino el nombre de mi dataframe
df_exams=pd.read_csv("StudentsPerformance.csv")

# %%
# show 5 first rows in a dataframe
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#show last 5
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df_exams.head(8)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# ...

# %%
df_exams.tail(4)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#acceso al tamaño de los atributos, es decir nro de filas y nro de columnas
df_exams.shape
# Out:
# (1000, 8)

# %%
#
pd.set_option("display.max_rows", 80)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...
